# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import Analyzer

# %%
lfr_Analyzer = Analyzer.Analyzer(158951)
elev_data = lfr_Analyzer.data[1]

# %%
length= list(lfr_Analyzer.data[0].values())[0][2]
print(length/ len(elev_data))
x = np.linspace(0,length,len(elev_data))
#print(x)
# Out:
# 0.019404672209174197

# %%
plt.plot(x,lfr_Analyzer.data[1])

# %%
dsl_acc_function_sample = [0]
ele = 0
for i in range(1,len(elev_data)):                                 
    if(int(float(elev_data[i]))>int(float(elev_data[i-1]))):
        ele += int(float(elev_data[i]))-int(float(elev_data[i-1]))
        dsl_acc_function_sample.append(ele)
    else:
        dsl_acc_function_sample.append(ele)

# %%
plt.plot(x,dsl_acc_function_sample)
