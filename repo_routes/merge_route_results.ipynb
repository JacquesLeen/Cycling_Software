# %%
print(5+3)

"""results = pd.read_csv(r'C:\Users\yd26114\Desktop\fc\Tables\All_Races_Results_Info.csv')
race_generic_info = pd.read_csv(r'C:\Users\yd26114\Desktop\fc\Tables\All_Races_Generic_Info.csv')
"""
"""
stages_results_1 = pd.read_csv(r"C:\Users\yd26114\Desktop\fc\Tables\All_Stages_Results_0_to_1000.csv")
stages_results_2 = pd.read_csv(r"C:\Users\yd26114\Desktop\fc\Tables\All_Stages_Results_1000_to_2000.csv")
stages_results_3 = pd.read_csv(r"C:\Users\yd26114\Desktop\fc\Tables\All_Stages_Results_2000_to_4000.csv")
stages_results_4 = pd.read_csv(r"C:\Users\yd26114\Desktop\fc\Tables\All_Stages_Results_3000_to_4000.csv")
stages_results_5 = pd.read_csv(r"C:\Users\yd26114\Desktop\fc\Tables\All_Stages_Results_4000_to_4347.csv")
"""
# Out:
#   File "C:\Users\yd26114\AppData\Local\Temp/ipykernel_11452/3370465430.py", line 5
#     """
#        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 26-27: truncated \UXXXXXXXX escape

# %%
display(results.head())
display(race_generic_info.head())
# Out:
#    Unnamed: 0 Pos           Rider  Born                  Team      Time  \
# 0           0  01  O'Grady Stuart  1973       Crédit Agricole  04:10:29
# 1           1  02      Drew Jamie  1973  Mercury Cycling Team      + 00
# 2           2  03  Rogers Michael  1979    Mapei - Quick Step      + 00
# 3           3  04   Hall Jonathan  1972       Festina - Lotus      + 00
# 4           4  05  Hughes Cameron  1972                     -      + 00
#
#   Time in Seconds Gap in Seconds Percentage of Winning Time  \
# 0           15029              0                        1.0
# 1           15029              0                        1.0
# 2           15029              0                        1.0
# 3           15029              0                        1.0
# 4           15029              0                        1.0
#
#                     Race  Year Gender Category  Race Code  Rider Code  \
# 0  Melbourne to Sorrento  2000    Men      1.5        886        15.0
# ...
